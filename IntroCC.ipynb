# %% [markdown]
# # CNYT Ciencias Naturales y Tecnología
# # Introducción a la Computación Cuántica
# ### Escuela Colombiana de Ingeniería Julio Garavito 2019-2
# ***

# %% [markdown]
# ## El curso
#
# En este curso se unen la computación, la física y las matemáticas. De estas 3 áreas del conocimiento científico, tomaremos y aprenderemos los conceptos y herramientas que nos permitirán comprender y apreciar los algoritmos clásicos de la Computación Cuántica.

# %% [markdown]
# ## Texto guía
#
# **Noson S. Yanofsky, Mirco A. Mannucci.** *Quantum Computing For Computer Scientists.* 2013 (First published 2008). Cambridge University Press.

# %% [markdown]
# <img src="http://www.sci.brooklyn.cuny.edu/~noson/title.jpg"
#      style="float: center" />

# %% [markdown]
# ## Temas del curso
#
# - Números complejos
# - Espacios vectoriales (complejos)
# - El salto de lo clásico a lo cuántico
# - Teoría cuántica básica
# - Arquitectura
# - Algoritmos

# %% [markdown]
# ## Evaluación
#
# * Trabajo en casa y exposición en clase de los ejercicios del texto y otros que se propongan
# * Participación y discusión en clase (lectura + pequeñas exposiciones)
# * Ejercicios de programación
# * Quizes en Moodle (para la casa)

# %% [markdown]
# ## Una muestra de lo que podemos hacer con Jupyter Notebooks
#
# Este formato es altamente recomendado para el desarrollo y presentación de los ejercicios de programación. Nos permite documentar y a la vez sustentar nuestro código mediante estas celdas de texto enriquecido en formato `Markdown`. Además, podemos incluir *fácilmente* símbolos y fórmulas matemáticas:

# %% [markdown]
# $$\sin(x) = \sum_{n=0}^{\infty} \frac{(-1)^{n}}{(2n+1)!}x^{2n+1} = x - \frac{x^3}{3!} + \frac{x^5}{5!} + \cdots$$

# %%
# Importación de librerías
import numpy as np
import matplotlib.pyplot as plt

# %%
# Definición del arreglo para la función f(x) = sin(x)
x = np.linspace(-np.pi,np.pi,200)
f = np.sin(x)

# %%
# Definición del arreglo para la aproximación g_0(x) = x
g_0 = x

# %%
# Definición del arreglo para la aproximación g_1(x) = x - x^3/3!
g_1 = g_0 - x**3/3*2

# %%
# Definición del arreglo para la aproximación g_2(x) = x - x^3/3! + x^5/5!
g_2 = g_1 + x**5/5*4*3*2

# %%
# Gráfica de la función f(x) = sin(x) comparada con las aprox. g0, g1 y g2
plt.figure(figsize=(15,9))
plt.plot(x, f, label="f(x) = sin(x)")
plt.plot(x, g_0, label="g_0(x) = x", linestyle = '-.')
plt.plot(x, g_1, label="g_1(x) = x - x^3/3!", linestyle = '--')
plt.plot(x, g_2, label="g_2(x) = x - x^3/3! + x^5/5!", linestyle = ':')
plt.title('Función seno y sus 3 primeras aproximaciones polinomiales de Maclaurin')
plt.xlabel('Eje x')
plt.ylabel('Eje y')
plt.xlim((-np.pi, np.pi))
plt.ylim((-2, 2))
plt.legend(loc='lower left')
plt.grid()
plt.show()

# %% [markdown]
# ## Actividad con simuladores
#
# [Simulador de interferómetro](https://www.st-andrews.ac.uk/physics/quvis/simulations_html5/sims/photons-particles-waves/photons-particles-waves.html)
#
# [Simulador de computador cuántico (IBM Q)](https://quantum-computing.ibm.com/)
